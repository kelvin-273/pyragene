# %%
# %pdb
# Out:
# Automatic pdb calling has been turned OFF

# %%
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

from sim import *
from collections import namedtuple
from functools import partial

# %% [markdown]
# # Sequential breeding with single-point crossover

# %% [markdown]
# ## Results

# %%
n_loci = 10
for i in range(n_loci+1):
    args = Args(
        n_loci,
        i,
        10,
        0.9,
        choose_parents_uniform,
        choose_intermediate_target,
        generate_initial_pop_trait_introgression,
        pruning=True
    )
    simulation(args)
# Out:
# /home/kelvin/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# mean: 0.0
# std: 0.0
# %success: 1.0
# /home/kelvin/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# mean: 0.535
# std: 2.833862205542111
# %success: 1.0
# ...
