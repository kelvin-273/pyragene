# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

from sim import *
from collections import namedtuple
from functools import partial

# %% [markdown]
# # Sequential breeding with single-point crossover

# %% [markdown]
# ## Questions to answer with this experiment
#
# - How do plant breeding simulations behave?
# - Can we replicate the

# %% [markdown]
# ## Results

# %%
n_loci = 10
for i in range((n_loci // 2) + 1):
    args = Args(
        n_loci,
        i,
        10,
        0.9,
        choose_parents_uniform,
        choose_intermediate_target_uniform,
        PopulationGenerators.generate_initial_pop_trait_introgression,
        pruning=True
    )
    simulation(args)
# Out:
# /home/kelvin/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# mean: 0.0
# std: 0.0
# %success: 1.0
# /home/kelvin/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# mean: 5.587
# std: 6.337225812609173
# %success: 1.0
# ...

# %% [markdown]
# ## Results
#
# ### Setup
#
# ### Explanations
#
# Max progeny per generation is arranged in discrete rows.
# This is because for number of progeny required to create the genotype from a set of parents is related to the inverse log of the number of ways that the genotype can be created from those parents, and that is discrete.
#
# Runs can take a huge number of generations to create the target, likely due excessive breeding of the original donor as opposed to backcrossing of with the recipient population.

# %%
n_loci = 10
for i in range((n_loci // 2) + 1):
    args = Args(
        n_loci,
        i,
        10,
        0.9,
        choose_parents_uniform,
        choose_intermediate_target_uniform,
        PopulationGenerators.generate_initial_pop_trait_introgression,
        resource_cap=500,
        pruning=True
    )
    simulation(args)
# Out:
# /home/kelvin/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# mean: 0.0
# std: 0.0
# %success: 1.0
# /home/kelvin/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# mean: 4.929
# std: 5.293577145938273
# %success: 1.0
# ...

# %%
Args?
